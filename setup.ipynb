# %%
# !pip install -r requirements.txt

# %%
# !python utils/download_models.py

# %%
gdrive_view_url = "https://drive.google.com/file/d/1Er7u7YLrtl99IL06HMi750Jyj1MUreh0/view?usp=drive_link"
# manually download raw audios for training
